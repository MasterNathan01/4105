# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterNathan01/4105/blob/main/WatersNathan_801283595_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# P1: one input at a time (plot error and find best theta values)
# P2: all three at the same time, expanding on question 1 (plot error and find best theta values)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def compute_cost(X,y,theta):
  predictions = X.dot(theta)
  error = np.subtract(predictions,y)
  sqrError = np.square(error)
  cost = (1/(2*m))*np.sum(sqrError)
  return cost

def gradient_descent(X,y,theta,alpha,iterations):
  cost_history = np.zeros(iterations)
  for i in range(iterations):
    predictions = X.dot(theta)
    error = np.subtract(predictions,y)
    sum_delta = (alpha/m) * X.transpose().dot(error)
    theta = theta - sum_delta
    cost_history[i] = compute_cost(X,y,theta)
  return theta,cost_history

#pulling data set
url = 'https://raw.githubusercontent.com/HamedTabkhi/Intro-to-ML/main/Dataset/D3.csv'

df = pd.read_csv(url)
X = df.values[:, 0]
y = df.values[:, 3]
m = len(y)
n= len(X)

X_0 = np.ones((m,1))
X_1 = X.reshape(m,1)
X = np.hstack((X_0,X_1))
theta = np.zeros(2)

theta = [0., 0.]
iterations = 10000
alpha = 0.01
theta, cost_history = gradient_descent(X,y,theta,alpha,iterations)
print('Theta =', theta)
print('Cost =', cost_history[-1])
print(f'linear model y ={theta[1]}x+ {theta[0]}')
# Out:
# Theta = [ 5.92794892 -2.03833663]
# Cost = 0.9849930825405946
# linear model y =-2.0383366331233708x+ 5.927948916706452

# %%
#Scatter Plot
plt.scatter(X[:, 1], y, color='red', marker='x', label='Training Data')
plt.plot(X[:, 1], np.dot(X, theta), color='blue', label = 'Regression Line')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(range(1, iterations+1), cost_history, color='red')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost History')
plt.grid(True)
plt.show()

# %%
X1 = df.values[:, 1]
X1 = np.hstack((np.ones((X1.shape[0], 1)), X1.reshape(-1, 1)))
y2 = df.values[:, 3]
theta1 =  np.zeros(2)
theta1, cost_history1 = gradient_descent(X1,y2,theta1,alpha,iterations)
cost = compute_cost(X1,y2,theta1)
print('Theta:', theta1)
print('Cost:', cost)
print(f'linear model y ={theta1[1]}x+ {theta1[0]}')

#Scatter Plot
plt.scatter(X1[:, 1], y, color='red', marker='x', label='Training Data')
plt.plot(X1[:, 1], np.dot(X1, theta1), color='blue', label = 'Regression Line')
plt.rcParams['figure.figsize'] = (10, 6)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Theta: [0.73606043 0.55760761]
# Cost: 3.5993660181680416
# linear model y =0.557607610373368x+ 0.7360604299900559

# %%
plt.plot(range(1, iterations+1), cost_history1, color='red')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost History')
plt.grid(True)
plt.show()

# %%
X2 = df.values[:, 2]
X2 = np.hstack((np.ones((X2.shape[0], 1)), X2.reshape(-1, 1)))
y3 = df.values[:, 3]
theta2 =  np.zeros(2)
theta2, cost_history2 = gradient_descent(X2,y3,theta2,alpha,iterations)
cost = compute_cost(X2,y3,theta2)
print('Theta:', theta2)
print('Cost:', cost)
print(f'linear model y ={theta2[1]}x+ {theta2[0]}')

#Scatter Plot
plt.scatter(X2[:, 1], y, color='red', marker='x', label='Training Data')
plt.plot(X2[:, 1], np.dot(X2, theta2), color='blue', label = 'Regression Line')
plt.rcParams['figure.figsize'] = (10, 6)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Theta: [ 2.8714221  -0.52048288]
# Cost: 3.6294511246079155
# linear model y =-0.5204828841235419x+ 2.871422103541768

# %%
plt.plot(range(1, iterations+1), cost_history2, color='red')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost History')
plt.grid(True)
plt.show()

# %%
X3 = df.values[:, 0:3]
X3 = np.hstack((np.ones((X3.shape[0], 1)), X3))
y4 = df.values[:, 3]
theta3 =  np.zeros(X3.shape[1])
theta3, cost_history3 = gradient_descent(X3,y4,theta3,alpha,iterations)
cost = compute_cost(X3,y,theta3)

print('Theta:', theta3)
print('Cost:', cost)
print(f'linear model y ={theta3[1]}x1+ {theta3[2]}x2+{theta3[3]}x3+{theta3[0]}')

xin = np.array([[1,1,1],[2,0,4],[3,2,1]])
xin_h = np.hstack((np.ones((xin.shape[0],1)),xin)) # Add a column of ones to xin, similar to X_0
y_pred = xin_h.dot(theta3)
print('y_pred =',y_pred)
# Out:
# Theta: [ 5.31392511 -2.00368507  0.53260334 -0.26556638]
# Cost: 0.7384642446895517
# linear model y =-2.0036850731222926x1+ 0.5326033358244937x2+-0.2655663837548432x3+5.313925107750003
# y_pred = [3.57727699 0.24428943 0.10251018]

# %%
plt.plot(range(1, iterations+1), cost_history3, color='red')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost History')
plt.grid(True)
plt.show()
